# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from refnx.analysis import CurveFitter
from refnx.reflect import Slab

# %%
# will need to add the repo directory to sys.path (system specific)
sys.path.append('../')

from structureSE import RI
from dataSE import DataSE
from reflect_modelSE import ReflectModelSE
from objectiveSE import ObjectiveSE

# %%
dname = 'testData1_16nm_PNIPAM_on_Si_EP4.dat'
data = DataSE(data=dname)

WVASE_test = pd.read_csv(open('WVASE_example_2nmSiO2_11nmPNIPAM_658nm.txt','r'))

# %%
si     = RI('../materials/silicon.csv')
sio2   = RI('../materials/silica.csv')
PNIPAM = RI('../materials/pnipam.csv')
air    = RI('../materials/air.csv')

polymer_layer = PNIPAM(15.0)
polymer_layer.name = 'PNIPAM'
polymer_layer.thick.setp(vary=True, bounds=(10,50))

silica_layer = sio2(2)
silica_layer.name = 'Silica'
silica_layer.thick.setp(vary=False, bounds=(0.1, 6))

struc = air() | polymer_layer | silica_layer | si()

model = ReflectModelSE(struc, wavelength=658)

model.DeltaOffset.setp(value=1, vary=True, bounds=(0,10))

# %% [markdown]
# # Comparison to WVASE output for 2nm SiO2 15nm PNIPAM system

# %%
fig, ax = plt.subplots()
axt = ax.twinx()

aois = np.linspace(50,75,100)
psi, delta = model(aois)

ax.plot(WVASE_test['Angle of Incidence'], WVASE_test['Psi'],ls='--', color='k', zorder=5, label='wvase')
axt.plot(WVASE_test['Angle of Incidence'], WVASE_test['Delta'],ls='--', color='k', zorder=5)

ax.plot(aois, psi, color='r', label='refnx')
axt.plot(aois, delta, color='r')

ax.legend(frameon=False)

ax.set(ylabel='Psi', xlabel='AOI (°)')
axt.set(ylabel='Delta')
plt.show()

# %% [markdown]
# # Fitting experimental Data

# %%
fig, ax = plt.subplots()
axt = ax.twinx()

aois = np.linspace(50,75,100)
psi, delta = model(aois)
ax.plot(aois, psi, color='r')
p = ax.scatter(data.aoi, data.psi, color='r')

axt.plot(aois, delta, color='b')
d = axt.scatter(data.aoi, data.delta, color='b')

ax.legend(handles=[p,d], labels=['Psi', 'Delta'])
ax.set(ylabel='Psi', xlabel='AOI, °')
axt.set(ylabel='Delta')
plt.show()

# %%
objective = ObjectiveSE(model, data)

# %%
fitter = CurveFitter(objective)
fitter.fit(method='differential_evolution');
# Out:
# 20it [00:01, 17.55it/s]

# %%
fig, ax = plt.subplots()
axt = ax.twinx()

aois = np.linspace(50,75,100)
psi, delta = model(aois)
ax.plot(aois, psi, color='r')
p = ax.scatter(data.aoi, data.psi, color='r')

axt.plot(aois, delta, color='b')
d = axt.scatter(data.aoi, data.delta, color='b')

ax.legend(handles=[p,d], labels=['Psi', 'Delta'])
ax.set(ylabel='Psi', xlabel='AOI, °')
axt.set(ylabel='Delta')
plt.show()

# %%
for i, x in enumerate(objective.model.parameters):
    print(x)
# Out:
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter: 'wavelength'  , value=658 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'delta offset' , value=0.23357 +/- 0.0749, bounds=[0.0, 10.0]>
# ________________________________________________________________________________
# Parameters: 'Structure - '
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:' - volfrac solvent', value=0 (fixed)  , bounds=[0.0, 1.0]>
# ________________________________________________________________________________
# Parameters:    'PNIPAM'
# <Parameter:  ' - thick'   , value=11.4088 +/- 0.0538, bounds=[10.0, 50.0]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:' - volfrac solvent', value=0 (fixed)  , bounds=[0.0, 1.0]>
# ________________________________________________________________________________
# Parameters:    'Silica'
# <Parameter:  ' - thick'   , value=2 (fixed)  , bounds=[0.1, 6.0]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:' - volfrac solvent', value=0 (fixed)  , bounds=[0.0, 1.0]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:' - volfrac solvent', value=0 (fixed)  , bounds=[0.0, 1.0]>
